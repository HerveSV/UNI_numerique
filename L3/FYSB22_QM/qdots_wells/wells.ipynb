# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
import scipy.constants as cst

# %%
data_wells = pd.read_csv("data/wells.csv", delimiter=";", decimal=",")

# %%
def get_max_index(X):
    max_index = 0
    for i in range(len(X)):
        if X[i] > X[max_index]:
            max_index = i

    return max_index

# %% [markdown]
# Of those 6 peaks, the highest energy gap is GaInP, lowest – GaAs. You
# need the positions of 4 peaks in between.

# %%
I = data_wells["Intensity Source #2"]
wavelength = data_wells["Wavelength (nm)"]*1e-9



plt.plot(wavelength, I)
plt.show()

# %%
Eg = 1.54 * cst.eV
# Out:
# 2.46735201636e-19

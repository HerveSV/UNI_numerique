# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Es = [0, 0.5, 1, 2]
for e in Es:
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
    theta = np.linspace(0, np.pi, 1000)
    r = e/(1-e*np.cos(theta))
    ax.plot(theta, r)
    plt.show()
# Out:
# /var/folders/fj/wq7sc0qj0sx0bjm834mnq_hw0000gn/T/ipykernel_84326/2236977480.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   r = e/(1-e*np.cos(theta))

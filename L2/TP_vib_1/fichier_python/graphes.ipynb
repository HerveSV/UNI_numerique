# %%
import sys
from scipy import *
from pylab import *
from scipy.optimize import curve_fit
import numpy as np
import pandas as pd
from uncertainties import ufloat

# %%
filepath = "/Users/hervesv/Documents/Stuff/Projects/UNI_numerique/L2/TP_vib_1/fichier_python/data/TP_pendule-20231002-HSV&PT/petits_angles/TP_Pendule_PA_2023-10-02_14-47-02_final-0.25kg.csv"
data = pd.read_csv(filepath, header=None)

#print(data)

print("yyeeeet")


data_n = data.transpose().to_numpy()
#print(data_n)

measures = [[[],[]] for i in range(5)]
c = 0


for i in range(len(measures)):
    for j in range(len(measures[i])):
        measures[i][j] = data_n[c]
        c += 1

#print(measures[1])

""" 2) Determine number of data points """

#datafile = open(filename, 'r')
#ndata = 0
#for line in datafile:
#    ndata = ndata + 1
#print("Number of data points =",ndata)
#datafile.close

""" 3) Fill in data array """

#data = np.zeros((ndata,2))

#datafile = open(sys.argv[1], 'r')
#ndata = 0
#for line in datafile:
#    words = line.split(',')
#    data[ndata,0] = words[0]
#    data[ndata,1] = words[1]
#    ndata = ndata + 1
#datafile.close

""" 4) Fit curve """

def sinusoide_amortie(t,amplitude,phase,period,damping,offset):
    return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset

def get_index_from_time(t,tab):
    if t < min(tab) or t > max(tab):
        return len(tab)-1
    else:
        for i in range(len(tab)-2):
            if t > tab[i] and t < tab[i+1]:
                return i
        return len(tab)-1
    

def calc_OC(R, l, h, m, mt, ma, n):
    return (m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)

def calc_IOx(R, l, h, radius, m, mt, ma, n):
    return m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

def calc_T0(IOx, OC, g, m, mt, ma):
    return 2*pi*sqrt(IOx/((m+mt+ma)*g*OC))

#theta_T = [np.zeros(2,1) for i in range(len(measures))]
theta0s250 = np.zeros(len(measures))
Ts250 = np.zeros(len(measures))
sig_Ts250 = np.zeros(len(measures))

for j in range(len(measures)):
      tmax = max(measures[j][0])
      #i = get_index_from_time(tmax,data[:,0])
      """print("Time t =",tmax,"Index i =",i)"""
      times = measures[j][0]
      angles = measures[j][1]
      params,cov = curve_fit(sinusoide_amortie,times,angles)
      t = linspace(0,tmax, 1000)
      (amplitude,phase,period,damping,offset) = params
      
      
      plt.plot(times,angles, 'o', color="r")
      plt.xlabel(r"$\theta$ (rad)")
      plt.xlabel("$t$ (s)")
      plt.title(rf"Évolution de $\theta$ en fonction de $t$, $\theta_0$={np.rad2deg(amplitude):.1f} deg.")
      
      plot(t,sinusoide_amortie(t,amplitude,phase,period,damping,offset), '-', zorder=-2)
      show()
      
      print("Fit over time interval [0;",tmax,"]")
      print("Amplitude theta0 =",'{:.3f}'.format(amplitude),"rad =",
            '{:.1f}'.format(amplitude*180/pi),"deg")
      print("Period T         =",'{:.3f}'.format(period),"s")
      print("Damping time     =",'{:.0f}'.format(damping),"s")
      print("Offset angle     =",'{:.3f}'.format(offset),"rad =",
            '{:.1f}'.format(offset*180/pi),"deg")

      """ 5) Theory """

      g = 9.81

      R = 0.032   # R = 3.2 cm
      sig_R = 0.002
      u_R = ufloat(R, sig_R)

      mc = 0.277 # kg
      sig_mc = 0.001
      u_mc = ufloat(mc, sig_mc)

      radius = 0.025 # r = 2.5 cm
      sig_radius = 0.001
      u_radius = ufloat(radius, sig_radius)
      
      h = 0.017      # h = 1.7 cm
      sig_h = 0.001
      u_h = ufloat(h, sig_h)
      
      n = 1
      
      m = n*mc
      sig_m = sig_mc*n
      u_m = n*u_mc
      
      mt = 0.24 #0.20
      sig_mt = 0.01
      u_mt = ufloat(mt, sig_mt)
      
      ma = 0.4 #0.565
      sig_ma = 0.01
      u_ma = ufloat(ma, sig_ma)

      l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
      sig_l = 0.001
      u_l = ufloat(l, sig_l)


      OC = calc_OC(R, l, h, m, mt, ma, n)#(m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)
      IOx = calc_IOx(R, l, h, radius, m, mt, ma, n)#m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2
      T0 = calc_T0(IOx, OC, g, m, mt, ma)#2*pi*np.sqrt(IOx/((m+mt+ma)*g*OC))

      max_OC = calc_OC(R+sig_R, l+sig_l, h+sig_h, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_OC = calc_OC(R-sig_R, l-sig_l, h-sig_h, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_OC = np.max([np.abs(OC-max_OC), np.abs(OC-min_OC)])

      max_IOx = calc_IOx(R+sig_R, l+sig_l, h+sig_h, radius+sig_radius, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_IOx = calc_IOx(R-sig_R, l-sig_l, h-sig_h, radius-sig_radius, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_IOx = np.max([np.abs(IOx-max_IOx), np.abs(IOx-min_IOx)])

      max_T0 = calc_T0(IOx+sig_IOx, OC-sig_OC, g, m-sig_m, mt-sig_mt, ma-sig_ma)
      min_T0 = calc_T0(IOx-sig_IOx, OC+sig_OC, g, m+sig_m, mt+sig_mt, ma+sig_ma)
      sig_T0 = np.max([np.abs(T0-max_T0), np.abs(T0-min_T0)])


      #u_OC = (u_m*(u_R+u_l+0.5*n*u_h)+u_mt*(u_R+u_l/2))/(u_mt+u_m+u_ma)
      #u_IOx = u_m*(u_R+l+n*u_h/2)**2+0.25*u_m*(u_radius**2+(n*u_h)**2/3) + u_mt*u_l**2/12+u_mt*(u_R+u_l/2)**2+0.5*u_ma*u_R**2
      #u_T0 = 2*pi*np.sqrt(u_IOx/((u_m+u_mt+u_ma)*g*u_OC))




      print("\nLength of the rod:   l =",'{:.1f}'.format(l*100),"cm")
      print("Mass of the rod:    mt =",'{:.0f}'.format(mt*1000),"g")
      print("Mass of axial disc: ma =",'{:.0f}'.format(ma*1000),"g")
      print("Total mass: M =",'{:.0f}'.format((m+ma+mt)*1000),"g")
      print("Center-of-mass distance from rotation axis: OC =",
            '{:.1f}'.format(OC*100),"cm")
      print("Harmonic period T0 =",'{:.3f}'.format(T0),"s")
      theta0 = np.abs(amplitude)
      TBorda = T0*(1+theta0**2/16)
      Texact = T0*(1+0.25*sin(theta0/2)**2)

      max_Texact = (T0+sig_T0)*(1+0.25*sin(theta0/2)**2)
      min_Texact = (T0-sig_T0)*(1+0.25*sin(theta0/2)**2)
      sig_Texact = np.max([np.abs(Texact-max_Texact), np.abs(Texact-min_Texact)])


      #u_Texact = u_T0*(1+0.25*sin(theta0/2)**2)
      print("Borda formula   T  =",'{:.3f}'.format(TBorda),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")
      print("Exact formula   T  =",'{:.3f}'.format(Texact),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")

      T0=period/(1+theta0**2/16)
      print("\nExperimentally deduced T0 =",'{:.3f}'.format(T0),"s")
      omega0=2*pi/T0
      alpha = l**2/12+(R+l/2)**2
      beta = m*(R+l+n*h/2)**2+ma*R**2/2
      gamma = R+l/2
      delta = m*(R+l+n*h/2)
      mt = (delta-omega0**2/g*beta)/(omega0**2/g*alpha-gamma)
      print("Experimentally deduced mass of the rod:   mt =",
            '{:.0f}'.format(mt*1000),"g")

      rho = mc/(pi*radius**2*h-pi*(0.5*0.007)**2*h)
      #rho = mc/(pi*radius**2*h) # hole neglected
      print("Estimated density of the rod: rho =",
            '{:.0f}'.format(rho),"kg/m^3")
      diameter = 0.0075 # Diameter of the rod (effective solid rod)
      mt = rho*pi*diameter**2/4*l
      print("Estimated mass of the rod (from density): mt =",
            '{:.0f}'.format(mt*1000),"g")
      
      theta0s250[j] = theta0
      Ts250[j] = Texact

      sig_Ts250[j] = sig_Texact

      print(Ts250)




      #quit()
# Out:
# yyeeeet
# Fit over time interval [0; 9.747 ]
# Amplitude theta0 = -0.087 rad = -5.0 deg
# Period T         = 1.482 s
# Damping time     = 8 s
# Offset angle     = 0.001 rad = 0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.496 s  (with theta0 = 0.087 rad)
# Exact formula   T  = 1.496 s  (with theta0 = 0.087 rad)
#
# Experimentally deduced T0 = 1.481 s
# Experimentally deduced mass of the rod:   mt = 302 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 0.         0.         0.         0.        ]
# Fit over time interval [0; 9.914 ]
# Amplitude theta0 = -0.115 rad = -6.6 deg
# Period T         = 1.507 s
# Damping time     = 24 s
# Offset angle     = 0.003 rad = 0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.497 s  (with theta0 = 0.115 rad)
# Exact formula   T  = 1.497 s  (with theta0 = 0.115 rad)
#
# Experimentally deduced T0 = 1.505 s
# Experimentally deduced mass of the rod:   mt = 203 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 0.         0.         0.        ]
# Fit over time interval [0; 9.972 ]
# Amplitude theta0 = -0.172 rad = -9.9 deg
# Period T         = 1.525 s
# Damping time     = 20 s
# Offset angle     = 0.000 rad = 0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.499 s  (with theta0 = 0.172 rad)
# Exact formula   T  = 1.499 s  (with theta0 = 0.172 rad)
#
# Experimentally deduced T0 = 1.522 s
# Experimentally deduced mass of the rod:   mt = 147 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 0.         0.        ]
# Fit over time interval [0; 9.989 ]
# Amplitude theta0 = -0.261 rad = -15.0 deg
# Period T         = 1.537 s
# Damping time     = 26 s
# Offset angle     = -0.001 rad = -0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.502 s  (with theta0 = 0.261 rad)
# Exact formula   T  = 1.502 s  (with theta0 = 0.261 rad)
#
# Experimentally deduced T0 = 1.531 s
# Experimentally deduced mass of the rod:   mt = 121 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 0.        ]
# Fit over time interval [0; 9.959 ]
# Amplitude theta0 = 0.345 rad = 19.8 deg
# Period T         = 1.547 s
# Damping time     = 29 s
# Offset angle     = -0.002 rad = -0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.507 s  (with theta0 = 0.345 rad)
# Exact formula   T  = 1.507 s  (with theta0 = 0.345 rad)
#
# Experimentally deduced T0 = 1.535 s
# Experimentally deduced mass of the rod:   mt = 109 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 1.50678225]

# %%
filepath = "/Users/hervesv/Documents/Stuff/Projects/UNI_numerique/L2/TP_vib_1/fichier_python/data/TP_pendule-20231002-HSV&PT/petits_angles/TP_Pendule_PA_2023-10-02_14-54-10_final-1kg.csv"
data = pd.read_csv(filepath, header=None)

#print(data)

#print("yyeeeet")


data_n = data.transpose().to_numpy()
#print(data_n)

measures = [[[],[]] for i in range(5)]
c = 0


for i in range(len(measures)):
    for j in range(len(measures[i])):
        measures[i][j] = data_n[c]
        c += 1

#print(measures[1])

""" 2) Determine number of data points """

#datafile = open(filename, 'r')
#ndata = 0
#for line in datafile:
#    ndata = ndata + 1
#print("Number of data points =",ndata)
#datafile.close

""" 3) Fill in data array """

#data = np.zeros((ndata,2))

#datafile = open(sys.argv[1], 'r')
#ndata = 0
#for line in datafile:
#    words = line.split(',')
#    data[ndata,0] = words[0]
#    data[ndata,1] = words[1]
#    ndata = ndata + 1
#datafile.close

""" 4) Fit curve """

def sinusoide_amortie(t,amplitude,phase,period,damping,offset):
    return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset

def get_index_from_time(t,tab):
    if t < min(tab) or t > max(tab):
        return len(tab)-1
    else:
        for i in range(len(tab)-2):
            if t > tab[i] and t < tab[i+1]:
                return i
        return len(tab)-1
    

#theta_T = [np.zeros(2,1) for i in range(len(measures))]
theta0s1kg = np.zeros(len(measures))
Ts1kg = np.zeros(len(measures))
sig_Ts1kg = np.zeros(len(measures))

for j in range(len(measures)):
      tmax = max(measures[j][0])
      #i = get_index_from_time(tmax,data[:,0])
      """print("Time t =",tmax,"Index i =",i)"""
      times = measures[j][0]
      angles = measures[j][1]
      params,cov = curve_fit(sinusoide_amortie,times,angles)
      t = linspace(0,tmax, 1000)
      (amplitude,phase,period,damping,offset) = params
      
      
      plt.plot(times,angles, 'o', color="r")
      plt.xlabel(r"$\theta$ (rad)")
      plt.xlabel("$t$ (s)")
      plt.title(rf"Évolution de $\theta$ en fonction de $t$, $\theta_0$={np.rad2deg(np.abs(amplitude)):.1f} deg.")
      
      plot(t,sinusoide_amortie(t,amplitude,phase,period,damping,offset), '-', zorder=-2)
      show()
      
      print("Fit over time interval [0;",tmax,"]")
      print("Amplitude theta0 =",'{:.3f}'.format(amplitude),"rad =",
            '{:.1f}'.format(amplitude*180/pi),"deg")
      print("Period T         =",'{:.3f}'.format(period),"s")
      print("Damping time     =",'{:.0f}'.format(damping),"s")
      print("Offset angle     =",'{:.3f}'.format(offset),"rad =",
            '{:.1f}'.format(offset*180/pi),"deg")

      """ 5) Theory """

      g = 9.81

      R = 0.032   # R = 3.2 cm
      sig_R = 0.002
      u_R = ufloat(R, sig_R)

      mc = 0.277 # kg
      sig_mc = 0.001
      u_mc = ufloat(mc, sig_mc)

      radius = 0.025 # r = 2.5 cm
      sig_radius = 0.001
      u_radius = ufloat(radius, sig_radius)
      
      h = 0.017      # h = 1.7 cm
      sig_h = 0.001
      u_h = ufloat(h, sig_h)
      
      n = 4
      
      m = n*mc
      sig_m = sig_mc*n
      u_m = n*u_mc
      
      mt = 0.24 #0.20
      sig_mt = 0.01
      u_mt = ufloat(mt, sig_mt)
      
      ma = 0.4 #0.565
      sig_ma = 0.01
      u_ma = ufloat(ma, sig_ma)

      l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
      sig_l = 0.001
      u_l = ufloat(l, sig_l)


      OC = calc_OC(R, l, h, m, mt, ma, n)#(m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)
      IOx = calc_IOx(R, l, h, radius, m, mt, ma, n)#m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2
      T0 = calc_T0(IOx, OC, g, m, mt, ma)#2*pi*np.sqrt(IOx/((m+mt+ma)*g*OC))

      max_OC = calc_OC(R+sig_R, l+sig_l, h+sig_h, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_OC = calc_OC(R-sig_R, l-sig_l, h-sig_h, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_OC = np.max([np.abs(OC-max_OC), np.abs(OC-min_OC)])

      max_IOx = calc_IOx(R+sig_R, l+sig_l, h+sig_h, radius+sig_radius, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_IOx = calc_IOx(R-sig_R, l-sig_l, h-sig_h, radius-sig_radius, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_IOx = np.max([np.abs(IOx-max_IOx), np.abs(IOx-min_IOx)])

      max_T0 = calc_T0(IOx+sig_IOx, OC-sig_OC, g, m-sig_m, mt-sig_mt, ma-sig_ma)
      min_T0 = calc_T0(IOx-sig_IOx, OC+sig_OC, g, m+sig_m, mt+sig_mt, ma+sig_ma)
      sig_T0 = np.max([np.abs(T0-max_T0), np.abs(T0-min_T0)])

      print("\nLength of the rod:   l =",'{:.1f}'.format(l*100),"cm")
      print("Mass of the rod:    mt =",'{:.0f}'.format(mt*1000),"g")
      print("Mass of axial disc: ma =",'{:.0f}'.format(ma*1000),"g")
      print("Total mass: M =",'{:.0f}'.format((m+ma+mt)*1000),"g")
      print("Center-of-mass distance from rotation axis: OC =",
            '{:.1f}'.format(OC*100),"cm")
      print("Harmonic period T0 =",'{:.3f}'.format(T0),"s")
      theta0 = np.abs(amplitude)
      TBorda = T0*(1+theta0**2/16)
      Texact = T0*(1+0.25*sin(theta0/2)**2)

      max_Texact = (T0+sig_T0)*(1+0.25*sin(theta0/2)**2)
      min_Texact = (T0-sig_T0)*(1+0.25*sin(theta0/2)**2)
      sig_Texact = np.max([np.abs(Texact-max_Texact), np.abs(Texact-min_Texact)])
      print("Borda formula   T  =",'{:.3f}'.format(TBorda),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")
      print("Exact formula   T  =",'{:.3f}'.format(Texact),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")

      T0=period/(1+theta0**2/16)
      print("\nExperimentally deduced T0 =",'{:.3f}'.format(T0),"s")
      omega0=2*pi/T0
      alpha = l**2/12+(R+l/2)**2
      beta = m*(R+l+n*h/2)**2+ma*R**2/2
      gamma = R+l/2
      delta = m*(R+l+n*h/2)
      mt = (delta-omega0**2/g*beta)/(omega0**2/g*alpha-gamma)
      print("Experimentally deduced mass of the rod:   mt =",
            '{:.0f}'.format(mt*1000),"g")

      rho = mc/(pi*radius**2*h-pi*(0.5*0.007)**2*h)
      #rho = mc/(pi*radius**2*h) # hole neglected
      print("Estimated density of the rod: rho =",
            '{:.0f}'.format(rho),"kg/m^3")
      diameter = 0.0075 # Diameter of the rod (effective solid rod)
      mt = rho*pi*diameter**2/4*l
      print("Estimated mass of the rod (from density): mt =",
            '{:.0f}'.format(mt*1000),"g")
      
      theta0s1kg[j] = theta0
      
      Ts1kg[j] = Texact
      sig_Ts1kg[j] = sig_Texact




      #quit()
# Out:
# Fit over time interval [0; 9.983 ]
# Amplitude theta0 = 0.078 rad = 4.5 deg
# Period T         = 1.606 s
# Damping time     = 84 s
# Offset angle     = -0.001 rad = -0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.585 s  (with theta0 = 0.078 rad)
# Exact formula   T  = 1.585 s  (with theta0 = 0.078 rad)
#
# Experimentally deduced T0 = 1.605 s
# Experimentally deduced mass of the rod:   mt = 58 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.934 ]
# Amplitude theta0 = -0.129 rad = -7.4 deg
# Period T         = 1.590 s
# Damping time     = 76 s
# Offset angle     = 0.003 rad = 0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.586 s  (with theta0 = 0.129 rad)
# Exact formula   T  = 1.586 s  (with theta0 = 0.129 rad)
#
# Experimentally deduced T0 = 1.589 s
# Experimentally deduced mass of the rod:   mt = 193 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.943 ]
# Amplitude theta0 = -0.168 rad = -9.7 deg
# Period T         = 1.599 s
# Damping time     = 65 s
# Offset angle     = 0.001 rad = 0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.587 s  (with theta0 = 0.168 rad)
# Exact formula   T  = 1.587 s  (with theta0 = 0.168 rad)
#
# Experimentally deduced T0 = 1.596 s
# Experimentally deduced mass of the rod:   mt = 129 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.996 ]
# Amplitude theta0 = 0.252 rad = 14.4 deg
# Period T         = 1.609 s
# Damping time     = 124 s
# Offset angle     = -0.001 rad = -0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.591 s  (with theta0 = 0.252 rad)
# Exact formula   T  = 1.591 s  (with theta0 = 0.252 rad)
#
# Experimentally deduced T0 = 1.603 s
# Experimentally deduced mass of the rod:   mt = 77 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.961 ]
# Amplitude theta0 = -0.339 rad = -19.4 deg
# Period T         = 1.612 s
# Damping time     = 81 s
# Offset angle     = 0.000 rad = 0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.596 s  (with theta0 = 0.339 rad)
# Exact formula   T  = 1.596 s  (with theta0 = 0.339 rad)
#
# Experimentally deduced T0 = 1.601 s
# Experimentally deduced mass of the rod:   mt = 95 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g

# %%
#print(np.zeros((2,1)))]

g = 9.81
R = 0.032   # R = 3.2 cm
mc = 0.277
radius = 0.025 # r = 2.5 cm
h = 0.017      # h = 1.7 cm
n = 1
m250 = mc
m1kg = 4*mc
mt = 0.24 #0.20
ma = 0.4 #0.565

l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
OC250 = (m250*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m250+ma)
IOx250 = m250*(R+l+n*h/2)**2+0.25*m250*(radius**2+(1*h)**2/3)
IOx250 = IOx250 + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

OC1kg = (m1kg*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m1kg+ma)
IOx1kg = m1kg*(R+l+n*h/2)**2+0.25*m1kg*(radius**2+(4*h)**2/3)
IOx1kg = IOx1kg + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

def T0_ideal(l, g):
    return 2*np.pi*np.sqrt(l/g)

def T0_real(M, g, OC, I):
    return 2*np.pi*np.sqrt(I/(M*g*OC))


print(sig_Ts250)
print(sig_Ts1kg)

plt.errorbar(np.rad2deg(theta0s250), Ts250, label="0.277 kg", yerr=sig_Ts250, fmt="o", color="orange")
plt.errorbar(np.rad2deg(theta0s1kg), Ts1kg, label=f"{0.277*4} kg", yerr=sig_Ts1kg, fmt="o", color="tab:blue" )
plt.xlabel(r"$\theta_0$ ($^{\circ}$)")
plt.ylabel("$T$ (s)")
plt.ylim((1,2))
print(f"OC250: {OC250}, l: {l}")
print(f"T0 ideal: {T0_ideal(l, g)}, {T0_ideal(OC250, g)}")
plt.axhline(T0_ideal(l, g), label=r"$T_{0, idéal}=2\pi\sqrt{l/g}$")
#plt.axhline(T0_real(m250+mt+ma, g, OC250, IOx250), label="$T_0$")
plt.legend()
plt.title(r"$T$ en fonction de $\theta_0$, $T_0$ idéal")
plt.savefig("figs/harmonique_ideal", dpi=300)
plt.show()

plt.errorbar(np.rad2deg(theta0s250), Ts250, label="0.277 kg", yerr=sig_Ts250, fmt="o", color="orange")
plt.errorbar(np.rad2deg(theta0s1kg), Ts1kg, label=f"{0.277*4} kg", yerr=sig_Ts1kg, fmt="o", color="tab:blue" )
plt.xlabel(r"$\theta_0$ ($^{\circ}$)")
plt.ylabel("$T$ (s)")
plt.ylim((1.4,1.7))
plt.axhline(T0_ideal(l, g), label=r"$T_{0, idéal}=2\pi\sqrt{l/g}$")
plt.axhline(T0_real(m250+mt+ma, g, OC250, IOx250), label=r"$T_{0, réaliste, 277g}$", color="gold")#label=r"$T_{0, réaliste, 277g}=2\pi\sqrt{I_{Ox}/(MgOC)}$", color="bisque")
plt.axhline(T0_real(m1kg+mt+ma, g, OC1kg, IOx1kg), label=r"$T_{0, réaliste, 1.1kg}$", color="skyblue")#label=r"$T_{0, réaliste, 1.1kg}=2\pi\sqrt{I_{Ox}/(MgOC)}$", color="lightblue")
plt.legend()
plt.title(r"Prédictions du modèle idéal et réaliste, régime harmonique")
plt.savefig("figs/harmonique_realiste", dpi=300)
plt.show()
# Out:
# [0.03680575 0.03681888 0.03685646 0.03694448 0.03705955]
# [0.02930915 0.02932848 0.02934989 0.02941332 0.02950704]
# OC250: 0.2717104689203925, l: 0.58
# T0 ideal: 1.5277748675525828, 1.0456793956674526

# %% [markdown]
# ### Grands Angles

# %%
filepath = "/Users/hervesv/Documents/Stuff/Projects/UNI_numerique/L2/TP_vib_1/fichier_python/data/TP_pendule-20231002-HSV&PT/grands_angles/TP_Pendule_GA_2023-10-02_15-07-47_final-0.25kg.csv"
data = pd.read_csv(filepath, header=None)

#print(data)

#print("yyeeeet")


data_n = data.transpose().to_numpy()
#print(data_n)

measures = [[[],[]] for i in range(5)]
c = 0


for i in range(len(measures)):
    for j in range(len(measures[i])):
        measures[i][j] = data_n[c]
        c += 1

#print(measures[1])

""" 2) Determine number of data points """

#datafile = open(filename, 'r')
#ndata = 0
#for line in datafile:
#    ndata = ndata + 1
#print("Number of data points =",ndata)
#datafile.close

""" 3) Fill in data array """

#data = np.zeros((ndata,2))

#datafile = open(sys.argv[1], 'r')
#ndata = 0
#for line in datafile:
#    words = line.split(',')
#    data[ndata,0] = words[0]
#    data[ndata,1] = words[1]
#    ndata = ndata + 1
#datafile.close

""" 4) Fit curve """

def sinusoide_amortie(t,amplitude,phase,period,damping,offset):
    return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset

def get_index_from_time(t,tab):
    if t < min(tab) or t > max(tab):
        return len(tab)-1
    else:
        for i in range(len(tab)-2):
            if t > tab[i] and t < tab[i+1]:
                return i
        return len(tab)-1
    

def calc_OC(R, l, h, m, mt, ma, n):
    return (m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)

def calc_IOx(R, l, h, radius, m, mt, ma, n):
    return m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

def calc_T0(IOx, OC, g, m, mt, ma):
    return 2*pi*sqrt(IOx/((m+mt+ma)*g*OC))

#theta_T = [np.zeros(2,1) for i in range(len(measures))]
g_theta0s250 = np.zeros(len(measures))
g_Ts250 = np.zeros(len(measures))
g_sig_Ts250 = np.zeros(len(measures))

for j in range(len(measures)):
      tmax = max(measures[j][0])
      #i = get_index_from_time(tmax,data[:,0])
      """print("Time t =",tmax,"Index i =",i)"""
      times = measures[j][0]
      angles = measures[j][1]
      params,cov = curve_fit(sinusoide_amortie,times,angles)
      t = linspace(0,tmax, 1000)
      (amplitude,phase,period,damping,offset) = params
      
      
      plt.plot(times,angles, 'o', color="r")
      plt.xlabel(r"$\theta$ (rad)")
      plt.xlabel("$t$ (s)")
      plt.title(rf"Évolution de $\theta$ en fonction de $t$, $\theta_0$={np.rad2deg(amplitude):.1f} deg.")
      
      plot(t,sinusoide_amortie(t,amplitude,phase,period,damping,offset), '-', zorder=-2)
      show()
      
      print("Fit over time interval [0;",tmax,"]")
      print("Amplitude theta0 =",'{:.3f}'.format(amplitude),"rad =",
            '{:.1f}'.format(amplitude*180/pi),"deg")
      print("Period T         =",'{:.3f}'.format(period),"s")
      print("Damping time     =",'{:.0f}'.format(damping),"s")
      print("Offset angle     =",'{:.3f}'.format(offset),"rad =",
            '{:.1f}'.format(offset*180/pi),"deg")

      """ 5) Theory """

      g = 9.81

      R = 0.032   # R = 3.2 cm
      sig_R = 0.002
      u_R = ufloat(R, sig_R)

      mc = 0.277 # kg
      sig_mc = 0.001
      u_mc = ufloat(mc, sig_mc)

      radius = 0.025 # r = 2.5 cm
      sig_radius = 0.001
      u_radius = ufloat(radius, sig_radius)
      
      h = 0.017      # h = 1.7 cm
      sig_h = 0.001
      u_h = ufloat(h, sig_h)
      
      n = 1
      
      m = n*mc
      sig_m = sig_mc*n
      u_m = n*u_mc
      
      mt = 0.24 #0.20
      sig_mt = 0.01
      u_mt = ufloat(mt, sig_mt)
      
      ma = 0.4 #0.565
      sig_ma = 0.01
      u_ma = ufloat(ma, sig_ma)

      l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
      sig_l = 0.001
      u_l = ufloat(l, sig_l)


      OC = calc_OC(R, l, h, m, mt, ma, n)#(m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)
      IOx = calc_IOx(R, l, h, radius, m, mt, ma, n)#m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2
      T0 = calc_T0(IOx, OC, g, m, mt, ma)#2*pi*np.sqrt(IOx/((m+mt+ma)*g*OC))

      max_OC = calc_OC(R+sig_R, l+sig_l, h+sig_h, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_OC = calc_OC(R-sig_R, l-sig_l, h-sig_h, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_OC = np.max([np.abs(OC-max_OC), np.abs(OC-min_OC)])

      max_IOx = calc_IOx(R+sig_R, l+sig_l, h+sig_h, radius+sig_radius, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_IOx = calc_IOx(R-sig_R, l-sig_l, h-sig_h, radius-sig_radius, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_IOx = np.max([np.abs(IOx-max_IOx), np.abs(IOx-min_IOx)])

      max_T0 = calc_T0(IOx+sig_IOx, OC-sig_OC, g, m-sig_m, mt-sig_mt, ma-sig_ma)
      min_T0 = calc_T0(IOx-sig_IOx, OC+sig_OC, g, m+sig_m, mt+sig_mt, ma+sig_ma)
      sig_T0 = np.max([np.abs(T0-max_T0), np.abs(T0-min_T0)])


      #u_OC = (u_m*(u_R+u_l+0.5*n*u_h)+u_mt*(u_R+u_l/2))/(u_mt+u_m+u_ma)
      #u_IOx = u_m*(u_R+l+n*u_h/2)**2+0.25*u_m*(u_radius**2+(n*u_h)**2/3) + u_mt*u_l**2/12+u_mt*(u_R+u_l/2)**2+0.5*u_ma*u_R**2
      #u_T0 = 2*pi*np.sqrt(u_IOx/((u_m+u_mt+u_ma)*g*u_OC))




      print("\nLength of the rod:   l =",'{:.1f}'.format(l*100),"cm")
      print("Mass of the rod:    mt =",'{:.0f}'.format(mt*1000),"g")
      print("Mass of axial disc: ma =",'{:.0f}'.format(ma*1000),"g")
      print("Total mass: M =",'{:.0f}'.format((m+ma+mt)*1000),"g")
      print("Center-of-mass distance from rotation axis: OC =",
            '{:.1f}'.format(OC*100),"cm")
      print("Harmonic period T0 =",'{:.3f}'.format(T0),"s")
      theta0 = np.abs(amplitude)
      TBorda = T0*(1+theta0**2/16)
      Texact = T0*(1+0.25*sin(theta0/2)**2)

      max_Texact = (T0+sig_T0)*(1+0.25*sin(theta0/2)**2)
      min_Texact = (T0-sig_T0)*(1+0.25*sin(theta0/2)**2)
      sig_Texact = np.max([np.abs(Texact-max_Texact), np.abs(Texact-min_Texact)])


      #u_Texact = u_T0*(1+0.25*sin(theta0/2)**2)
      print("Borda formula   T  =",'{:.3f}'.format(TBorda),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")
      print("Exact formula   T  =",'{:.3f}'.format(Texact),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")

      T0=period/(1+theta0**2/16)
      print("\nExperimentally deduced T0 =",'{:.3f}'.format(T0),"s")
      omega0=2*pi/T0
      alpha = l**2/12+(R+l/2)**2
      beta = m*(R+l+n*h/2)**2+ma*R**2/2
      gamma = R+l/2
      delta = m*(R+l+n*h/2)
      mt = (delta-omega0**2/g*beta)/(omega0**2/g*alpha-gamma)
      print("Experimentally deduced mass of the rod:   mt =",
            '{:.0f}'.format(mt*1000),"g")

      rho = mc/(pi*radius**2*h-pi*(0.5*0.007)**2*h)
      #rho = mc/(pi*radius**2*h) # hole neglected
      print("Estimated density of the rod: rho =",
            '{:.0f}'.format(rho),"kg/m^3")
      diameter = 0.0075 # Diameter of the rod (effective solid rod)
      mt = rho*pi*diameter**2/4*l
      print("Estimated mass of the rod (from density): mt =",
            '{:.0f}'.format(mt*1000),"g")
      
      g_theta0s250[j] = theta0
      g_Ts250[j] = Texact

      g_sig_Ts250[j] = sig_Texact

      print(g_Ts250)




      #quit()
# Out:
# Fit over time interval [0; 9.967 ]
# Amplitude theta0 = -0.346 rad = -19.8 deg
# Period T         = 1.552 s
# Damping time     = 35 s
# Offset angle     = 0.004 rad = 0.3 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.507 s  (with theta0 = 0.346 rad)
# Exact formula   T  = 1.507 s  (with theta0 = 0.346 rad)
#
# Experimentally deduced T0 = 1.541 s
# Experimentally deduced mass of the rod:   mt = 94 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.50684664 0.         0.         0.         0.        ]
# Fit over time interval [0; 9.959 ]
# Amplitude theta0 = 0.639 rad = 36.6 deg
# Period T         = 1.590 s
# Damping time     = 41 s
# Offset angle     = -0.001 rad = -0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.534 s  (with theta0 = 0.639 rad)
# Exact formula   T  = 1.533 s  (with theta0 = 0.639 rad)
#
# Experimentally deduced T0 = 1.551 s
# Experimentally deduced mass of the rod:   mt = 68 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.50684664 1.53260328 0.         0.         0.        ]
# Fit over time interval [0; 9.96 ]
# Amplitude theta0 = 0.940 rad = 53.9 deg
# Period T         = 1.630 s
# Damping time     = 40 s
# Offset angle     = -0.001 rad = -0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.578 s  (with theta0 = 0.940 rad)
# Exact formula   T  = 1.573 s  (with theta0 = 0.940 rad)
#
# Experimentally deduced T0 = 1.545 s
# Experimentally deduced mass of the rod:   mt = 83 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.50684664 1.53260328 1.57252348 0.         0.        ]
# /var/folders/fj/wq7sc0qj0sx0bjm834mnq_hw0000gn/T/ipykernel_6930/2787652293.py:48: RuntimeWarning: overflow encountered in exp
#   return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset
# Fit over time interval [0; 9.957 ]
# Amplitude theta0 = 1.257 rad = 72.0 deg
# Period T         = 1.695 s
# Damping time     = 47 s
# Offset angle     = 0.004 rad = 0.2 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.644 s  (with theta0 = 1.257 rad)
# Exact formula   T  = 1.625 s  (with theta0 = 1.257 rad)
#
# Experimentally deduced T0 = 1.542 s
# Experimentally deduced mass of the rod:   mt = 90 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.50684664 1.53260328 1.57252348 1.62507262 0.        ]
# Fit over time interval [0; 9.949 ]
# Amplitude theta0 = 1.576 rad = 90.3 deg
# Period T         = 1.772 s
# Damping time     = 42 s
# Offset angle     = 0.005 rad = 0.3 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.728 s  (with theta0 = 1.576 rad)
# Exact formula   T  = 1.684 s  (with theta0 = 1.576 rad)
#
# Experimentally deduced T0 = 1.533 s
# Experimentally deduced mass of the rod:   mt = 114 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.50684664 1.53260328 1.57252348 1.62507262 1.68376674]

# %%
filepath = "/Users/hervesv/Documents/Stuff/Projects/UNI_numerique/L2/TP_vib_1/fichier_python/data/TP_pendule-20231002-HSV&PT/grands_angles/TP_Pendule_GA_2023-10-02_14-59-59_final-1kg.csv"
data = pd.read_csv(filepath, header=None)

#print(data)

#print("yyeeeet")


data_n = data.transpose().to_numpy()
#print(data_n)

measures = [[[],[]] for i in range(5)]
c = 0


for i in range(len(measures)):
    for j in range(len(measures[i])):
        measures[i][j] = data_n[c]
        c += 1

#print(measures[1])

""" 2) Determine number of data points """

#datafile = open(filename, 'r')
#ndata = 0
#for line in datafile:
#    ndata = ndata + 1
#print("Number of data points =",ndata)
#datafile.close

""" 3) Fill in data array """

#data = np.zeros((ndata,2))

#datafile = open(sys.argv[1], 'r')
#ndata = 0
#for line in datafile:
#    words = line.split(',')
#    data[ndata,0] = words[0]
#    data[ndata,1] = words[1]
#    ndata = ndata + 1
#datafile.close

""" 4) Fit curve """

def sinusoide_amortie(t,amplitude,phase,period,damping,offset):
    return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset

def get_index_from_time(t,tab):
    if t < min(tab) or t > max(tab):
        return len(tab)-1
    else:
        for i in range(len(tab)-2):
            if t > tab[i] and t < tab[i+1]:
                return i
        return len(tab)-1
    

#theta_T = [np.zeros(2,1) for i in range(len(measures))]
g_theta0s1kg = np.zeros(len(measures))
g_Ts1kg = np.zeros(len(measures))
g_sig_Ts1kg = np.zeros(len(measures))

for j in range(len(measures)):
      tmax = max(measures[j][0])
      #i = get_index_from_time(tmax,data[:,0])
      """print("Time t =",tmax,"Index i =",i)"""
      times = measures[j][0]
      angles = measures[j][1]
      params,cov = curve_fit(sinusoide_amortie,times,angles)
      t = linspace(0,tmax, 1000)
      (amplitude,phase,period,damping,offset) = params
      
      
      plt.plot(times,angles, 'o', color="r")
      plt.xlabel(r"$\theta$ (rad)")
      plt.xlabel("$t$ (s)")
      plt.title(rf"Évolution de $\theta$ en fonction de $t$, $\theta_0$={np.rad2deg(np.abs(amplitude)):.1f} deg.")
      
      plot(t,sinusoide_amortie(t,amplitude,phase,period,damping,offset), '-', zorder=-2)
      show()
      
      print("Fit over time interval [0;",tmax,"]")
      print("Amplitude theta0 =",'{:.3f}'.format(amplitude),"rad =",
            '{:.1f}'.format(amplitude*180/pi),"deg")
      print("Period T         =",'{:.3f}'.format(period),"s")
      print("Damping time     =",'{:.0f}'.format(damping),"s")
      print("Offset angle     =",'{:.3f}'.format(offset),"rad =",
            '{:.1f}'.format(offset*180/pi),"deg")

      """ 5) Theory """

      g = 9.81

      R = 0.032   # R = 3.2 cm
      sig_R = 0.002
      u_R = ufloat(R, sig_R)

      mc = 0.277 # kg
      sig_mc = 0.001
      u_mc = ufloat(mc, sig_mc)

      radius = 0.025 # r = 2.5 cm
      sig_radius = 0.001
      u_radius = ufloat(radius, sig_radius)
      
      h = 0.017      # h = 1.7 cm
      sig_h = 0.001
      u_h = ufloat(h, sig_h)
      
      n = 4
      
      m = n*mc
      sig_m = sig_mc*n
      u_m = n*u_mc
      
      mt = 0.24 #0.20
      sig_mt = 0.01
      u_mt = ufloat(mt, sig_mt)
      
      ma = 0.4 #0.565
      sig_ma = 0.01
      u_ma = ufloat(ma, sig_ma)

      l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
      sig_l = 0.001
      u_l = ufloat(l, sig_l)


      OC = calc_OC(R, l, h, m, mt, ma, n)#(m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)
      IOx = calc_IOx(R, l, h, radius, m, mt, ma, n)#m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2
      T0 = calc_T0(IOx, OC, g, m, mt, ma)#2*pi*np.sqrt(IOx/((m+mt+ma)*g*OC))

      max_OC = calc_OC(R+sig_R, l+sig_l, h+sig_h, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_OC = calc_OC(R-sig_R, l-sig_l, h-sig_h, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_OC = np.max([np.abs(OC-max_OC), np.abs(OC-min_OC)])

      max_IOx = calc_IOx(R+sig_R, l+sig_l, h+sig_h, radius+sig_radius, m+sig_m, mt+sig_mt, ma+sig_ma, n)
      min_IOx = calc_IOx(R-sig_R, l-sig_l, h-sig_h, radius-sig_radius, m-sig_m, mt-sig_mt, ma-sig_ma, n)
      sig_IOx = np.max([np.abs(IOx-max_IOx), np.abs(IOx-min_IOx)])

      max_T0 = calc_T0(IOx+sig_IOx, OC-sig_OC, g, m-sig_m, mt-sig_mt, ma-sig_ma)
      min_T0 = calc_T0(IOx-sig_IOx, OC+sig_OC, g, m+sig_m, mt+sig_mt, ma+sig_ma)
      sig_T0 = np.max([np.abs(T0-max_T0), np.abs(T0-min_T0)])

      print("\nLength of the rod:   l =",'{:.1f}'.format(l*100),"cm")
      print("Mass of the rod:    mt =",'{:.0f}'.format(mt*1000),"g")
      print("Mass of axial disc: ma =",'{:.0f}'.format(ma*1000),"g")
      print("Total mass: M =",'{:.0f}'.format((m+ma+mt)*1000),"g")
      print("Center-of-mass distance from rotation axis: OC =",
            '{:.1f}'.format(OC*100),"cm")
      print("Harmonic period T0 =",'{:.3f}'.format(T0),"s")
      theta0 = np.abs(amplitude)
      TBorda = T0*(1+theta0**2/16)
      Texact = T0*(1+0.25*sin(theta0/2)**2)

      max_Texact = (T0+sig_T0)*(1+0.25*sin(theta0/2)**2)
      min_Texact = (T0-sig_T0)*(1+0.25*sin(theta0/2)**2)
      sig_Texact = np.max([np.abs(Texact-max_Texact), np.abs(Texact-min_Texact)])
      print("Borda formula   T  =",'{:.3f}'.format(TBorda),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")
      print("Exact formula   T  =",'{:.3f}'.format(Texact),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")

      T0=period/(1+theta0**2/16)
      print("\nExperimentally deduced T0 =",'{:.3f}'.format(T0),"s")
      omega0=2*pi/T0
      alpha = l**2/12+(R+l/2)**2
      beta = m*(R+l+n*h/2)**2+ma*R**2/2
      gamma = R+l/2
      delta = m*(R+l+n*h/2)
      mt = (delta-omega0**2/g*beta)/(omega0**2/g*alpha-gamma)
      print("Experimentally deduced mass of the rod:   mt =",
            '{:.0f}'.format(mt*1000),"g")

      rho = mc/(pi*radius**2*h-pi*(0.5*0.007)**2*h)
      #rho = mc/(pi*radius**2*h) # hole neglected
      print("Estimated density of the rod: rho =",
            '{:.0f}'.format(rho),"kg/m^3")
      diameter = 0.0075 # Diameter of the rod (effective solid rod)
      mt = rho*pi*diameter**2/4*l
      print("Estimated mass of the rod (from density): mt =",
            '{:.0f}'.format(mt*1000),"g")
      
      g_theta0s1kg[j] = theta0
      
      g_Ts1kg[j] = Texact
      g_sig_Ts1kg[j] = sig_Texact




      #quit()
# Out:
# Fit over time interval [0; 9.949 ]
# Amplitude theta0 = -0.337 rad = -19.3 deg
# Period T         = 1.614 s
# Damping time     = 95 s
# Offset angle     = -0.001 rad = -0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.596 s  (with theta0 = 0.337 rad)
# Exact formula   T  = 1.596 s  (with theta0 = 0.337 rad)
#
# Experimentally deduced T0 = 1.602 s
# Experimentally deduced mass of the rod:   mt = 82 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.972 ]
# Amplitude theta0 = -0.604 rad = -34.6 deg
# Period T         = 1.644 s
# Damping time     = 129 s
# Offset angle     = -0.004 rad = -0.3 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.621 s  (with theta0 = 0.604 rad)
# Exact formula   T  = 1.620 s  (with theta0 = 0.604 rad)
#
# Experimentally deduced T0 = 1.607 s
# Experimentally deduced mass of the rod:   mt = 40 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.995 ]
# Amplitude theta0 = 0.891 rad = 51.1 deg
# Period T         = 1.691 s
# Damping time     = 611 s
# Offset angle     = -0.005 rad = -0.3 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.663 s  (with theta0 = 0.891 rad)
# Exact formula   T  = 1.658 s  (with theta0 = 0.891 rad)
#
# Experimentally deduced T0 = 1.611 s
# Experimentally deduced mass of the rod:   mt = 16 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.946 ]
# Amplitude theta0 = 1.273 rad = 72.9 deg
# Period T         = 1.766 s
# Damping time     = 109 s
# Offset angle     = 0.000 rad = 0.0 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.745 s  (with theta0 = 1.273 rad)
# Exact formula   T  = 1.724 s  (with theta0 = 1.273 rad)
#
# Experimentally deduced T0 = 1.604 s
# Experimentally deduced mass of the rod:   mt = 68 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# Fit over time interval [0; 9.958 ]
# Amplitude theta0 = 1.498 rad = 85.8 deg
# Period T         = 1.853 s
# Damping time     = 191 s
# Offset angle     = -0.016 rad = -0.9 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.807 s  (with theta0 = 1.498 rad)
# Exact formula   T  = 1.768 s  (with theta0 = 1.498 rad)
#
# Experimentally deduced T0 = 1.625 s
# Experimentally deduced mass of the rod:   mt = -91 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g

# %%
g = 9.81
R = 0.032   # R = 3.2 cm
mc = 0.277
radius = 0.025 # r = 2.5 cm
h = 0.017      # h = 1.7 cm
n = 1
m250 = mc
m1kg = 4*mc
mt = 0.24 #0.20
ma = 0.4 #0.565

l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
OC250 = (m250*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m250+ma)
IOx250 = m250*(R+l+n*h/2)**2+0.25*m250*(radius**2+(1*h)**2/3)
IOx250 = IOx250 + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

OC1kg = (m1kg*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m1kg+ma)
IOx1kg = m1kg*(R+l+n*h/2)**2+0.25*m1kg*(radius**2+(4*h)**2/3)
IOx1kg = IOx1kg + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

def T0_real(M, g, OC, I):
    return 2*np.pi*np.sqrt(I/(M*g*OC))

def T0_ideal(l, g):
    return 2*np.pi*np.sqrt(l/g)

def T_borda(T0, theta0):
    return T0*(1+theta0**2/16)

print(f"OC1kg: {OC1kg}, l: {l}")

print(sig_Ts250)
print(sig_Ts1kg)

#plt.errorbar(g_theta0s250, g_Ts250, label="0.277 kg", yerr=g_sig_Ts250, fmt="o", color="orange")
plt.errorbar(np.rad2deg(g_theta0s1kg), g_Ts1kg, label=f"{0.277*4} kg", yerr=g_sig_Ts1kg, fmt="o", color="tab:blue" )
plt.xlabel(r"$\theta_0$ $(^{\circ})$")
plt.ylabel("$T$ (s)")

g_theta0s1kg = np.array(g_theta0s1kg)
theta0_theo = np.linspace(np.deg2rad(15), np.deg2rad(90), 100)

T_borda_ideal = T_borda(T0_ideal(l, g), theta0_theo)
print(T_borda_ideal)

plt.plot(np.rad2deg(theta0_theo), T_borda_ideal, label="$T_{borda, idéal}$", color="skyblue")


plt.ylim((1,2.5))


print(f"T ideal: {T0_ideal(l, g)}, T real: {T0_real(m1kg+mt+ma, g, OC1kg, IOx1kg)}")

#print(f"OC250: {OC250}, l: {l}")
#print(f"T0 ideal: {T0_ideal(l, g)}, {T0_ideal(OC250, g)}")
#plt.axhline(T0_ideal(l, g), label=r"$T_{0, idéal}=2\pi\sqrt{OC/g}$")
#plt.axhline(T0_real(m250+mt+ma, g, OC250, IOx250), label="$T_0$")
plt.legend()
plt.title(rf"$T$ en fonction de $\theta_0$, m = {m1kg} kg")
#plt.savefig("figs/harmonique_ideal", dpi=300)
#plt.savefig("figs/anharm_ideal", dpi=300)
plt.show()


T_borda_real = T_borda(T0_real(m1kg+mt+ma, g, OC1kg, IOx1kg), theta0_theo)
plt.errorbar(np.rad2deg(g_theta0s1kg), g_Ts1kg, label=f"{0.277*4} kg", yerr=g_sig_Ts1kg, fmt="o", color="tab:blue" )
plt.plot(np.rad2deg(theta0_theo), T_borda_ideal, label="$T_{borda, idéal}$", color="skyblue", zorder=-2)
plt.plot(np.rad2deg(theta0_theo), T_borda_real, label="$T_{borda, réaliste}$", color="mediumspringgreen", zorder=-2)

plt.ylim((1.5,1.9))
plt.legend()
plt.title(r"Prédictions du modèle idéal et réaliste, régime anharmonique")

plt.xlabel(r"$\theta_0$ $(^{\circ})$")
plt.ylabel("$T$ (s)")
#plt.savefig("figs/anharm_realiste", dpi=300)
plt.show()


plt.plot(np.rad2deg(theta0_theo), 10000*T_borda_ideal, label="$T_{borda, idéal}$", color="skyblue", zorder=-2)
plt.plot(np.rad2deg(theta0_theo), 10000*T_borda_real, label="$T_{borda, réaliste}$", color="mediumspringgreen", zorder=-2)
plt.show()
'''
plt.errorbar(theta0s250, Ts250, label="0.277 kg", yerr=sig_Ts250, fmt="o", color="orange")
plt.errorbar(theta0s1kg, Ts1kg, label=f"{0.277*4} kg", yerr=sig_Ts1kg, fmt="o", color="tab:blue" )
plt.xlabel(r"$\theta_0$ (rad)")
plt.ylabel("T (s)")
plt.ylim((1.4,1.7))
#plt.axhline(T0_ideal(OC250, g), label=r"$T_{0, idéal}=2\pi\sqrt{OC/g}$")
plt.axhline(T0_real(m250+mt+ma, g, OC250, IOx250), label=r"$T_{0, réaliste, 277g}$", color="bisque")#label=r"$T_{0, réaliste, 277g}=2\pi\sqrt{I_{Ox}/(MgOC)}$", color="bisque")
plt.axhline(T0_real(m1kg+mt+ma, g, OC1kg, IOx1kg), label=r"$T_{0, réaliste, 1.1kg}$", color="lightblue")#label=r"$T_{0, réaliste, 1.1kg}=2\pi\sqrt{I_{Ox}/(MgOC)}$", color="lightblue")
plt.legend()
plt.title(r"$T$ en fonction de $\theta_0$, $T_0$ réaliste")
#plt.savefig("figs/harmonique_realiste", dpi=300)
plt.show()
'''
# Out:
# OC1kg: 0.4375251716247139, l: 0.58
# [0.03680575 0.03681888 0.03685646 0.03694448 0.03705955]
# [0.02930915 0.02932848 0.02934989 0.02941332 0.02950704]
# [1.53431937 1.53499712 1.53570827 1.53645279 1.53723071 1.53804201
#  1.5388867  1.53976478 1.54067624 1.54162109 1.54259932 1.54361095
#  1.54465596 1.54573436 1.54684614 1.54799131 1.54916987 1.55038181
#  1.55162714 1.55290586 1.55421797 1.55556346 1.55694234 1.55835461
#  1.55980026 1.5612793  1.56279173 1.56433754 1.56591674 1.56752933
#  1.56917531 1.57085467 1.57256742 1.57431355 1.57609307 1.57790598
#  1.57975228 1.58163196 1.58354503 1.58549149 1.58747133 1.58948456
#  1.59153118 1.59361119 1.59572458 1.59787136 1.60005152 1.60226507
#  1.60451201 1.60679234 1.60910605 1.61145315 1.61383364 1.61624751
#  1.61869477 1.62117542 1.62368945 1.62623688 1.62881768 1.63143188
#  1.63407946 1.63676043 1.63947479 1.64222253 1.64500366 1.64781818
#  1.65066608 1.65354737 1.65646205 1.65941011 1.66239156 1.6654064
#  1.66845463 1.67153624 1.67465124 1.67779962 1.6809814  1.68419655
#  1.6874451  1.69072703 1.69404236 1.69739106 1.70077316 1.70418864
#  1.70763751 1.71111976 1.7146354  1.71818443 1.72176685 1.72538265
#  1.72903184 1.73271441 1.73643038 1.74017973 1.74396247 1.74777859
#  1.7516281  1.755511   1.75942728 1.76337695]
# T ideal: 1.5277748675525828, T real: 1.5541347914128332
# '\nplt.errorbar(theta0s250, Ts250, label="0.277 kg", yerr=sig_Ts250, fmt="o", color="orange")\nplt.errorbar(theta0s1kg, Ts1kg, label=f"{0.277*4} kg", yerr=sig_Ts1kg, fmt="o", color="tab:blue" )\nplt.xlabel(r"$\theta_0$ (rad)")\nplt.ylabel("T (s)")\nplt.ylim((1.4,1.7))\n#plt.axhline(T0_ideal(OC250, g), label=r"$T_{0, idéal}=2\\pi\\sqrt{OC/g}$")\nplt.axhline(T0_real(m250+mt+ma, g, OC250, IOx250), label=r"$T_{0, réaliste, 277g}$", color="bisque")#label=r"$T_{0, réaliste, 277g}=2\\pi\\sqrt{I_{Ox}/(MgOC)}$", color="bisque")\nplt.axhline(T0_real(m1kg+mt+ma, g, OC1kg, IOx1kg), label=r"$T_{0, réaliste, 1.1kg}$", color="lightblue")#label=r"$T_{0, réaliste, 1.1kg}=2\\pi\\sqrt{I_{Ox}/(MgOC)}$", color="lightblue")\nplt.legend()\nplt.title(r"$T$ en fonction de $\theta_0$, $T_0$ réaliste")\n#plt.savefig("figs/harmonique_realiste", dpi=300)\nplt.show()\n'

# %%
filepath = "/Users/hervesv/Documents/Stuff/Projects/UNI_numerique/L2/TP_vib_1/fichier_python/data/TP_pendule-20231002-HSV&PT/dependane_masse/TP_Pendule_DM_2023-10-02_15-18-09_final-15deg.csv"
data = pd.read_csv(filepath, header=None)

#print(data)

print("yyeeeet")


data_n = data.transpose().to_numpy()
#print(data_n)

measures = [[[],[]] for i in range(4)]
c = 0


for i in range(len(measures)):
    for j in range(len(measures[i])):
        measures[i][j] = data_n[c]
        c += 1

#print(measures[1])

""" 2) Determine number of data points """

#datafile = open(filename, 'r')
#ndata = 0
#for line in datafile:
#    ndata = ndata + 1
#print("Number of data points =",ndata)
#datafile.close

""" 3) Fill in data array """

#data = np.zeros((ndata,2))

#datafile = open(sys.argv[1], 'r')
#ndata = 0
#for line in datafile:
#    words = line.split(',')
#    data[ndata,0] = words[0]
#    data[ndata,1] = words[1]
#    ndata = ndata + 1
#datafile.close

""" 4) Fit curve """

def sinusoide_amortie(t,amplitude,phase,period,damping,offset):
    return amplitude*cos(2*pi*t/period-phase)*exp(-t/damping)+offset

def get_index_from_time(t,tab):
    if t < min(tab) or t > max(tab):
        return len(tab)-1
    else:
        for i in range(len(tab)-2):
            if t > tab[i] and t < tab[i+1]:
                return i
        return len(tab)-1
    

def calc_OC(R, l, h, m, mt, ma, n):
    return (m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)

def calc_IOx(R, l, h, radius, m, mt, ma, n):
    return m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

def calc_T0(IOx, OC, g, m, mt, ma):
    return 2*pi*sqrt(IOx/((m+mt+ma)*g*OC))

#theta_T = [np.zeros(2,1) for i in range(len(measures))]
masses = np.array([0.277, 2*0.277, 3*0.277, 4*0.277])   #np.zeros(len(measures))
n = np.array([1, 2, 3, 4]) # same dimensions as np.array masses
Ts_m = np.zeros(len(measures))
sig_Ts_m = np.zeros(len(measures))

for j in range(len(measures)):
      tmax = max(measures[j][0])
      #i = get_index_from_time(tmax,data[:,0])
      """print("Time t =",tmax,"Index i =",i)"""
      times = measures[j][0]
      angles = measures[j][1]
      params,cov = curve_fit(sinusoide_amortie,times,angles)
      t = linspace(0,tmax, 1000)
      (amplitude,phase,period,damping,offset) = params
      
      
      plt.plot(times,angles, 'o', color="r")
      plt.xlabel(r"$\theta$ (rad)")
      plt.xlabel("$t$ (s)")
      plt.title(rf"Évolution de $\theta$ en fonction de $t$, $\theta_0$={np.rad2deg(amplitude):.1f} deg.")
      
      plot(t,sinusoide_amortie(t,amplitude,phase,period,damping,offset), '-', zorder=-2)
      show()
      
      print("Fit over time interval [0;",tmax,"]")
      print("Amplitude theta0 =",'{:.3f}'.format(amplitude),"rad =",
            '{:.1f}'.format(amplitude*180/pi),"deg")
      print("Period T         =",'{:.3f}'.format(period),"s")
      print("Damping time     =",'{:.0f}'.format(damping),"s")
      print("Offset angle     =",'{:.3f}'.format(offset),"rad =",
            '{:.1f}'.format(offset*180/pi),"deg")

      """ 5) Theory """

      g = 9.81

      R = 0.032   # R = 3.2 cm
      sig_R = 0.002
      u_R = ufloat(R, sig_R)

      mc = 0.277 # kg
      sig_mc = 0.001
      u_mc = ufloat(mc, sig_mc)

      radius = 0.025 # r = 2.5 cm
      sig_radius = 0.001
      u_radius = ufloat(radius, sig_radius)
      
      h = 0.017      # h = 1.7 cm
      sig_h = 0.001
      u_h = ufloat(h, sig_h)
      
      #n = 1
      
      m = n[j]*mc
      sig_m = sig_mc*n[j]
      u_m = n[j]*u_mc
      
      mt = 0.24 #0.20
      sig_mt = 0.01
      u_mt = ufloat(mt, sig_mt)
      
      ma = 0.4 #0.565
      sig_ma = 0.01
      u_ma = ufloat(ma, sig_ma)

      l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm
      sig_l = 0.001
      u_l = ufloat(l, sig_l)


      OC = calc_OC(R, l, h, m, mt, ma, n[j])#(m*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m+ma)
      IOx = calc_IOx(R, l, h, radius, m, mt, ma, n[j])#m*(R+l+n*h/2)**2+0.25*m*(radius**2+(n*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2
      T0 = calc_T0(IOx, OC, g, m, mt, ma)#2*pi*np.sqrt(IOx/((m+mt+ma)*g*OC))

      max_OC = calc_OC(R+sig_R, l+sig_l, h+sig_h, m+sig_m, mt+sig_mt, ma+sig_ma, n[j])
      min_OC = calc_OC(R-sig_R, l-sig_l, h-sig_h, m-sig_m, mt-sig_mt, ma-sig_ma, n[j])
      sig_OC = np.max([np.abs(OC-max_OC), np.abs(OC-min_OC)])

      max_IOx = calc_IOx(R+sig_R, l+sig_l, h+sig_h, radius+sig_radius, m+sig_m, mt+sig_mt, ma+sig_ma, n[j])
      min_IOx = calc_IOx(R-sig_R, l-sig_l, h-sig_h, radius-sig_radius, m-sig_m, mt-sig_mt, ma-sig_ma, n[j])
      sig_IOx = np.max([np.abs(IOx-max_IOx), np.abs(IOx-min_IOx)])

      max_T0 = calc_T0(IOx+sig_IOx, OC-sig_OC, g, m-sig_m, mt-sig_mt, ma-sig_ma)
      min_T0 = calc_T0(IOx-sig_IOx, OC+sig_OC, g, m+sig_m, mt+sig_mt, ma+sig_ma)
      sig_T0 = np.max([np.abs(T0-max_T0), np.abs(T0-min_T0)])


      #u_OC = (u_m*(u_R+u_l+0.5*n*u_h)+u_mt*(u_R+u_l/2))/(u_mt+u_m+u_ma)
      #u_IOx = u_m*(u_R+l+n*u_h/2)**2+0.25*u_m*(u_radius**2+(n*u_h)**2/3) + u_mt*u_l**2/12+u_mt*(u_R+u_l/2)**2+0.5*u_ma*u_R**2
      #u_T0 = 2*pi*np.sqrt(u_IOx/((u_m+u_mt+u_ma)*g*u_OC))




      print("\nLength of the rod:   l =",'{:.1f}'.format(l*100),"cm")
      print("Mass of the rod:    mt =",'{:.0f}'.format(mt*1000),"g")
      print("Mass of axial disc: ma =",'{:.0f}'.format(ma*1000),"g")
      print("Total mass: M =",'{:.0f}'.format((m+ma+mt)*1000),"g")
      print("Center-of-mass distance from rotation axis: OC =",
            '{:.1f}'.format(OC*100),"cm")
      print("Harmonic period T0 =",'{:.3f}'.format(T0),"s")
      theta0 = np.abs(amplitude)
      TBorda = T0*(1+theta0**2/16)
      Texact = T0*(1+0.25*sin(theta0/2)**2)

      max_Texact = (T0+sig_T0)*(1+0.25*sin(theta0/2)**2)
      min_Texact = (T0-sig_T0)*(1+0.25*sin(theta0/2)**2)
      sig_Texact = np.max([np.abs(Texact-max_Texact), np.abs(Texact-min_Texact)])


      #u_Texact = u_T0*(1+0.25*sin(theta0/2)**2)
      print("Borda formula   T  =",'{:.3f}'.format(TBorda),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")
      print("Exact formula   T  =",'{:.3f}'.format(Texact),
            "s  (with theta0 =",'{:.3f}'.format(theta0),"rad)")

      T0=period/(1+theta0**2/16)
      print("\nExperimentally deduced T0 =",'{:.3f}'.format(T0),"s")
      omega0=2*pi/T0
      alpha = l**2/12+(R+l/2)**2
      beta = m*(R+l+n[j]*h/2)**2+ma*R**2/2
      gamma = R+l/2
      delta = m*(R+l+n[j]*h/2)
      mt = (delta-omega0**2/g*beta)/(omega0**2/g*alpha-gamma)
      print("Experimentally deduced mass of the rod:   mt =", f"{mt*1000:.0f} g")#'{:.0f}'.format(mt*1000),"g")

      rho = mc/(pi*radius**2*h-pi*(0.5*0.007)**2*h)
      #rho = mc/(pi*radius**2*h) # hole neglected
      print("Estimated density of the rod: rho =",'{:.0f}'.format(rho),"kg/m^3")
      diameter = 0.0075 # Diameter of the rod (effective solid rod)
      mt = rho*pi*diameter**2/4*l
      print("Estimated mass of the rod (from density): mt =", f"{mt*1000:.0f} g")#'{:.0f}'.format(mt*1000),"g")
      
      
      Ts_m[j] = Texact

      sig_Ts_m[j] = sig_Texact

      print(Ts250)



print(f"Masss : {masses}")
print(f"Periods : {Ts_m} ± {sig_Ts_m}")
      #quit()
# Out:
# yyeeeet
# Fit over time interval [0; 9.951 ]
# Amplitude theta0 = -0.260 rad = -14.9 deg
# Period T         = 1.551 s
# Damping time     = 27 s
# Offset angle     = 0.002 rad = 0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 917 g
# Center-of-mass distance from rotation axis: OC = 27.2 cm
# Harmonic period T0 = 1.496 s
# Borda formula   T  = 1.502 s  (with theta0 = 0.260 rad)
# Exact formula   T  = 1.502 s  (with theta0 = 0.260 rad)
#
# Experimentally deduced T0 = 1.545 s
# Experimentally deduced mass of the rod:   mt = 83 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 1.50678225]
# Fit over time interval [0; 9.98 ]
# Amplitude theta0 = -0.258 rad = -14.8 deg
# Period T         = 1.586 s
# Damping time     = 43 s
# Offset angle     = 0.001 rad = 0.1 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1194 g
# Center-of-mass distance from rotation axis: OC = 35.7 cm
# Harmonic period T0 = 1.541 s
# Borda formula   T  = 1.547 s  (with theta0 = 0.258 rad)
# Exact formula   T  = 1.547 s  (with theta0 = 0.258 rad)
#
# Experimentally deduced T0 = 1.580 s
# Experimentally deduced mass of the rod:   mt = 49 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 1.50678225]
# Fit over time interval [0; 9.898 ]
# Amplitude theta0 = -0.252 rad = -14.4 deg
# Period T         = 1.596 s
# Damping time     = 64 s
# Offset angle     = 0.007 rad = 0.4 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1471 g
# Center-of-mass distance from rotation axis: OC = 41.3 cm
# Harmonic period T0 = 1.566 s
# Borda formula   T  = 1.572 s  (with theta0 = 0.252 rad)
# Exact formula   T  = 1.572 s  (with theta0 = 0.252 rad)
#
# Experimentally deduced T0 = 1.590 s
# Experimentally deduced mass of the rod:   mt = 72 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 1.50678225]
# Fit over time interval [0; 9.977 ]
# Amplitude theta0 = -0.252 rad = -14.4 deg
# Period T         = 1.607 s
# Damping time     = 75 s
# Offset angle     = 0.005 rad = 0.3 deg
#
# Length of the rod:   l = 58.0 cm
# Mass of the rod:    mt = 240 g
# Mass of axial disc: ma = 400 g
# Total mass: M = 1748 g
# Center-of-mass distance from rotation axis: OC = 45.4 cm
# Harmonic period T0 = 1.585 s
# Borda formula   T  = 1.591 s  (with theta0 = 0.252 rad)
# Exact formula   T  = 1.591 s  (with theta0 = 0.252 rad)
#
# Experimentally deduced T0 = 1.600 s
# Experimentally deduced mass of the rod:   mt = 98 g
# Estimated density of the rod: rho = 8464 kg/m^3
# Estimated mass of the rod (from density): mt = 217 g
# [1.49646342 1.49699727 1.49852504 1.50210408 1.50678225]
# Masss : [0.277 0.554 0.831 1.108]
# Periods : [1.50201875 1.54711032 1.57200389 1.59082544] ± [0.03694239 0.03222333 0.02920251 0.02941368]

# %%
g = 9.81
R = 0.032   # R = 3.2 cm
mc = 0.277
radius = 0.025 # r = 2.5 cm
h = 0.017      # h = 1.7 cm
mt = 0.24 #0.20
ma = 0.4 #0.565

l = 0.58 # 0.66-(R+n*h/2)  # l = 58 cm


'''
OC250 = (m250*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m250+ma)
IOx250 = m250*(R+l+n*h/2)**2+0.25*m250*(radius**2+(1*h)**2/3)
IOx250 = IOx250 + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

OC1kg = (m1kg*(R+l+0.5*n*h)+mt*(R+l/2))/(mt+m1kg+ma)
IOx1kg = m1kg*(R+l+n*h/2)**2+0.25*m1kg*(radius**2+(4*h)**2/3)
IOx1kg = IOx1kg + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2

'''

n_theo = np.linspace(0.5, 100, 100)
masses_theo = n_theo*mc

OC_m_ideal = (masses_theo*(R+l+0.5*n_theo*h)+mt*(R+l/2))/(masses_theo)
IOx_m_ideal = masses_theo*(R+l+n_theo*h/2)**2 + 0.25*masses_theo*(radius**2+(n_theo*h)**2/3)


n_const = 4
OC_m_ideal_constn = (masses_theo*(R+l+0.5*n_const*h))/(masses_theo)
IOx_m_ideal_constn = masses_theo*(R+l+n_const*h/2)**2 + 0.25*masses_theo*(radius**2+(n_const*h)**2/3)

OC_m_constn = (masses_theo*(R+l+0.5*n_const*h)+mt*(R+l/2))/(mt+masses_theo+ma)
IOx_m_constn = masses_theo*(R+l+n_const*h/2)**2 + 0.25*masses_theo*(radius**2+(n_const*h)**2/3) + mt*l**2/12 + mt*(R+l/2)**2 + 0.5*ma*R**2

#ma = 0
#mt = 0
OC_m = (masses_theo*(R+l+0.5*n_theo*h)+mt*(R+l/2))/(mt+masses_theo+ma)
IOx_m = masses_theo*(R+l+n_theo*h/2)**2 + 0.25*masses_theo*(radius**2+(n_theo*h)**2/3) + mt*l**2/12+mt*(R+l/2)**2+0.5*ma*R**2


theta0 = np.deg2rad(15)


def T0_real(M, g, OC, I):
    return 2*np.pi*np.sqrt(I/(M*g*OC))

def T0_ideal(l, g):
    return 2*np.pi*np.sqrt(l/g)

def T_borda(T0, theta0):
    return T0*(1+theta0**2/16)

#print(f"OC1kg: {OC1kg}, l: {l}")

#print(sig_Ts250)
#print(sig_Ts1kg)

T_borda_mc = T_borda(T0_real(masses_theo+ma+mt, g, OC_m, IOx_m), theta0)
T_borda_mc_ideal = T_borda(T0_real(masses_theo, g, OC_m_ideal, IOx_m_ideal), theta0) #T_borda(T0_real(masses_theo, g, OC_mideal, IOx_mideal), theta0)
T_borda_mc_constn = T_borda(T0_real(masses_theo+ma+mt, g, OC_m_constn, IOx_m_constn), theta0) #T_borda(2*np.pi*np.sqrt((masses_theo*(R+l+n_const*h/2)**2 + 0.25*masses_theo*(radius**2+(n_const*h)**2/3) + mt*l**2/12 + mt*(R+l/2)**2 + 0.5*ma*R**2)/(g*(masses_theo*(R+l+0.5*n_const*h)+mt*(R+l/2)))), theta0) #
T_borda_mc_ideal_constn = T_borda(T0_real(masses_theo, g, OC_m_ideal_constn, IOx_m_ideal_constn), theta0)
#T_borda_m_ideal = 2*np.pi*np.sqrt((g*(R+l+n_const*h/2))/((R+l+n_const*h/2)**2 + 0.25*(radius**2 + (n_const*h)**2/3)))

plt.errorbar(masses, Ts_m, label=f"$T=f(M_c)$", yerr=sig_Ts_m, fmt="o", color="tab:blue" )
plt.ylim((1.45, 1.65))
plt.title("Période $T$ en fonction de la masse des cylindres $M_c$")
plt.xlabel("$M_c$ (kg)")
plt.ylabel("$T$ (s)")

plt.legend()
plt.savefig("figs/fmass_dataonly", dpi=300)
plt.show()

plt.errorbar(masses, Ts_m, label=f"$T=f(M_c)$", yerr=sig_Ts_m, fmt="o", color="tab:blue" )
#plt.plot(masses_theo, T_borda_mc, color="r")
#plt.plot(masses_theo, T_borda_mc_ideal, color="g")
plt.plot(masses_theo, T_borda_mc_constn, color="b", label="$T_{réaliste}$")
plt.plot(masses_theo, T_borda_mc_ideal_constn, color="r", label="$T_{idéal}$")
#plt.plot(masses_theo, T_borda_m_ideal)#, color="r")
#plt.ylim((1.45, 1.65))
plt.xlabel("$M_c$ (kg)")
plt.ylabel("$T$ (s)")
plt.title("$T=f(M_c)$ avec prédictions des modèles")
plt.legend()
#plt.savefig("figs/fmass_models", dpi=300)
plt.show()
# I suppose we use that

#print(T_borda_mc)

# %%
A = (R+l+n_const*h/2)**2 + 0.25*(radius**2 + (n_const*h)**2/3)
B = 1/12*l**2 + (R+l/2)**2
C = 1/2*R**2
D = (R+l+n_const*h/2)
E = R+l/2

T0_exp = Ts_m/(1 + theta0**2/16)

F = (T0_exp/(2*np.pi))**2

mt_exp = (-ma*C + n*mc*(D*g*F - A))/(B - E*g*F)

mt_exp = np.array(mt_exp)
print(mt_exp)

sig_ma = 0.12

sig_mt_exp2 = np.max([np.abs(mt_exp-(-(ma+sig_ma)*C + n*mc*(D*g*F - A))/(B - E*g*F)), np.abs(mt_exp-(-(ma-sig_ma)*C + n*mc*(D*g*F - A))/(B - E*g*F))])

mean_mt = np.mean(mt_exp)
sig_mt_exp = np.sqrt(np.sum([(x-mean_mt)**2  for x in mt_exp])/(len(mt_exp)))
print(f"{mean_mt:.03f} ± {sig_mt_exp:.03f} or ± {sig_mt_exp2}")
# Out:
# [0.3488809  0.35499466 0.32027235 0.24480768]
# 0.317 ± 0.044 or ± 0.001299985560433925
